# %% [markdown]
# ## Image segmentation using U-Nets (Data Science Bowl 2018)
#
# #### Segmentation of nuclei in microscopy images
# The segmentation of nuclei in microscopy images is a common task in many workflows. Most traditional image processing methods are created for one specific type of image, and perform poorly on others.
#
# The aim is to develop a general-purpose algorithm to segment cell nuclei from any type of microscopy images.
#
# <img src="images/nuclei_image_types.png" style="width: 600px;"/>
#
# ---
#
# We will use a U-Net Convolutional Neural Network to perform this task. This notebook is adapted from [Keras U-Net starter by Kjetil Åmdal-Sævik](https://www.kaggle.com/keegil/keras-u-net-starter-lb-0-277?scriptVersionId=2164855) ([Licensed under the Apache License, Version 2.0](http://www.apache.org/licenses/LICENSE-2.0))
#
#
# **For more information, see the original publication about the 2018 Data Science Bowl:**
#
# [Caicedo, J.C., Goodman, A., Karhohs, K.W. et al.
# Nucleus segmentation across imaging experiments: the 2018 Data Science Bowl.
# Nat Methods 16, 1247–1253 (2019)](https://doi.org/10.1038/s41592-019-0612-7)
#
# We will be using some data from the original challenge (hosted at [https://www.kaggle.com/c/data-science-bowl-2018](https://www.kaggle.com/c/data-science-bowl-2018) (account required), and also from the [Broad Institute](https://bbbc.broadinstitute.org/BBBC038)). A copy is stored at **INSERT HPC LOCATION**

# %% [markdown]
# ### We begin by loading and visualising some of the data

# %%
import os
import numpy as np

from pathlib import Path
from tqdm import tqdm
from skimage.io import imread
from skimage.transform import resize


def load_images(
    path_data, image_width=128, image_height=128, num_channels=3, debug=False
):
    """
    Load all images into memory, and do some preprocessing (e.g. rescaling)

    :param path_data: Location of the data on disk (pathlib object)
    :param image_width: Image width in pixels for resizing
    :param image_height: Image height in pixels for resizing
    :param num_channels: Final number of channels required

    :return images, masks: Numpy array of images, and segmentation masks
    """

    path_data = Path(path_data)

    filenames = next(os.walk(path_data))[1]
    if debug:
        filenames = filenames[:20]

    images = np.zeros(
        (len(filenames), image_height, image_width, num_channels),
        dtype=np.uint8,
    )
    masks = np.zeros(
        (len(filenames), image_height, image_width, 1), dtype=np.bool
    )

    for n, image_id in tqdm(enumerate(filenames), total=len(filenames)):
        img = imread(path_data / image_id / "images" / (image_id + ".png"))[
            :, :, :num_channels
        ]
        img = resize(
            img,
            (image_height, image_width),
            mode="constant",
            preserve_range=True,
        )
        images[n] = img
        mask = np.zeros((image_height, image_width, 1), dtype=np.bool)

        mask_dir = path_data / image_id / "masks"
        for mask_file in next(os.walk(mask_dir))[2]:
            mask_ = imread(mask_dir / mask_file)
            mask_ = np.expand_dims(
                resize(
                    mask_,
                    (image_height, image_width),
                    mode="constant",
                    preserve_range=True,
                ),
                axis=-1,
            )
            mask = np.maximum(mask, mask_)
        masks[n] = mask
    return images, masks

# %%
# Where the data is stored
path_data = "/data/scratch/DCO/DIGOPS/SCIENCOM/atyson01/datasets/data-science-bowl-2018/stage1_train/"

DEBUG = True  # Set to True to only load a fraction of the raw data

images, masks = load_images(path_data, debug=DEBUG)
# Out:
# 100%|██████████| 20/20 [00:05<00:00,  3.48it/s]

# %%
# Visualise some raw data and segmentation masks
import random

import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid


def plot_raw_data(
    raw_images, masks, num_to_plot=2, fig_size=(10, 10), axes_pad=0.1
):
    """
    Plot raw data

    :param raw_images: Array of raw data images
    :param masks: Array of mask images
    :param num_to_plot: How many random images to plot
    :param fig_size: Tuple of overall figure size
    :param axes_pad: Seperation of individual images
    """

    idx_to_plot = tuple(random.sample(range(0, len(raw_images)), num_to_plot))

    raw_images = raw_images[tuple([idx_to_plot])]
    masks = np.squeeze(masks)[tuple([idx_to_plot])]

    fig = plt.figure(figsize=fig_size)
    grid = ImageGrid(
        fig,
        111,
        nrows_ncols=(num_to_plot, 2),
        axes_pad=axes_pad,
    )

    images = []
    for a, b in zip(raw_images, masks):
        images.extend([a, b])

    for ax, im in zip(grid, images):
        ax.imshow(im)
        ax.axis("off")

    grid[0].title.set_text("Raw data")
    grid[1].title.set_text("Segmentation masks")


plot_raw_data(images, masks, num_to_plot=5)

# %% [markdown]
# ### Now we'll build a model to segment these images
#
# We'll be using the popular [U-Net architecture](https://arxiv.org/abs/1505.04597)
#
# <img src="images/unet.png" style="width: 400px;"/>

# %%
from keras.models import Model
from keras.layers import Input
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.preprocessing.image import ImageDataGenerator


def build_unet(image_width=128, image_height=128, num_channels=3):
    inputs = Input((image_height, image_width, num_channels))
    s = Lambda(lambda x: x / 255)(inputs)

    c1 = Conv2D(8, (3, 3), activation="relu", padding="same")(inputs)
    c1 = Conv2D(8, (3, 3), activation="relu", padding="same")(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(16, (3, 3), activation="relu", padding="same")(p1)
    c2 = Conv2D(16, (3, 3), activation="relu", padding="same")(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(32, (3, 3), activation="relu", padding="same")(p2)
    c3 = Conv2D(32, (3, 3), activation="relu", padding="same")(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(64, (3, 3), activation="relu", padding="same")(p3)
    c4 = Conv2D(64, (3, 3), activation="relu", padding="same")(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)

    c5 = Conv2D(128, (3, 3), activation="relu", padding="same")(p4)
    c5 = Conv2D(128, (3, 3), activation="relu", padding="same")(c5)

    u6 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding="same")(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(64, (3, 3), activation="relu", padding="same")(u6)
    c6 = Conv2D(64, (3, 3), activation="relu", padding="same")(c6)

    u7 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding="same")(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(32, (3, 3), activation="relu", padding="same")(u7)
    c7 = Conv2D(32, (3, 3), activation="relu", padding="same")(c7)

    u8 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding="same")(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(16, (3, 3), activation="relu", padding="same")(u8)
    c8 = Conv2D(16, (3, 3), activation="relu", padding="same")(c8)

    u9 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding="same")(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(8, (3, 3), activation="relu", padding="same")(u9)
    c9 = Conv2D(8, (3, 3), activation="relu", padding="same")(c9)

    outputs = Conv2D(1, (1, 1), activation="sigmoid")(c9)
    model = Model(inputs=[inputs], outputs=[outputs])
    return model
# Out:
# 2021-11-15 12:18:17.929368: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-11-15 12:18:17.929395: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
import tensorflow as tf

model = build_unet()
model.compile(
    loss="binary_crossentropy",
    optimizer=tf.keras.optimizers.Adam(0.0001),
    metrics=[
        tf.keras.metrics.MeanIoU(num_classes=2),
        tf.keras.metrics.Recall(),
        tf.keras.metrics.Precision(),
    ],
)
# Out:
# 2021-11-15 12:18:19.972272: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-11-15 12:18:19.972346: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2021-11-15 12:18:19.972404: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2021-11-15 12:18:19.972459: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2021-11-15 12:18:19.972515: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2021-11-15 12:18:19.972570: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2021-11-15 12:18:19.972625: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2021-11-15 12:18:19.972680: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2021-11-15 12:18:19.972690: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-11-15 12:18:19.972916: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Split the dataset into a train (80%) and test (20%) fraction

# %%
from sklearn.model_selection import train_test_split

test_fraction = 0.2

(images_train, images_test, masks_train, masks_test,) = train_test_split(
    images,
    masks,
    test_size=test_fraction,
)

# %% [markdown]
# ### Train the model

# %%
epochs = 100  # Number of iterations over the full dataset
batch_size = 32  # Number of samples per gradient update
validation_split = 0.1  # In addition to test dataset, use 10% of data to assess performance during training

model.fit(
    images_train,
    masks_train,
    validation_split=validation_split,
    batch_size=batch_size,
    epochs=epochs,
)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 2.1168 - mean_io_u: 0.4557 - recall: 0.9613 - precision: 0.1458 - val_loss: 2.2994 - val_mean_io_u: 0.3916 - val_recall: 0.9682 - val_precision: 0.2252
# Epoch 2/100
# 1/1 [==============================] - 0s 319ms/step - loss: 1.9544 - mean_io_u: 0.4543 - recall: 0.9576 - precision: 0.1456 - val_loss: 2.0760 - val_mean_io_u: 0.3915 - val_recall: 0.9655 - val_precision: 0.2251
# Epoch 3/100
# 1/1 [==============================] - 0s 309ms/step - loss: 1.8020 - mean_io_u: 0.4530 - recall: 0.9544 - precision: 0.1457 - val_loss: 1.8735 - val_mean_io_u: 0.3908 - val_recall: 0.9612 - val_precision: 0.2248
# Epoch 4/100
# 1/1 [==============================] - 0s 305ms/step - loss: 1.6622 - mean_io_u: 0.4513 - recall: 0.9510 - precision: 0.1458 - val_loss: 1.6941 - val_mean_io_u: 0.3906 - val_recall: 0.9575 - val_precision: 0.2246
# Epoch 5/100
# 1/1 [==============================] - 0s 303ms/step - loss: 1.5359 - mean_io_u: 0.4495 - recall: 0.9467 - precision: 0.1459 - val_loss: 1.5367 - val_mean_io_u: 0.3895 - val_recall: 0.9507 - val_precision: 0.2239
# Epoch 6/100
# 1/1 [==============================] - 0s 312ms/step - loss: 1.4249 - mean_io_u: 0.4480 - recall: 0.9414 - precision: 0.1459 - val_loss: 1.4035 - val_mean_io_u: 0.3895 - val_recall: 0.9438 - val_precision: 0.2233
# Epoch 7/100
# 1/1 [==============================] - 0s 308ms/step - loss: 1.3295 - mean_io_u: 0.4470 - recall: 0.9355 - precision: 0.1459 - val_loss: 1.2972 - val_mean_io_u: 0.3892 - val_recall: 0.9337 - val_precision: 0.2225
# Epoch 8/100
# 1/1 [==============================] - 0s 313ms/step - loss: 1.2518 - mean_io_u: 0.4458 - recall: 0.9287 - precision: 0.1461 - val_loss: 1.2126 - val_mean_io_u: 0.3888 - val_recall: 0.9202 - val_precision: 0.2219
# Epoch 9/100
# 1/1 [==============================] - 0s 302ms/step - loss: 1.1871 - mean_io_u: 0.4446 - recall: 0.9207 - precision: 0.1464 - val_loss: 1.1447 - val_mean_io_u: 0.3885 - val_recall: 0.9040 - val_precision: 0.2255
# Epoch 10/100
# 1/1 [==============================] - 0s 308ms/step - loss: 1.1324 - mean_io_u: 0.4434 - recall: 0.9116 - precision: 0.1476 - val_loss: 1.0928 - val_mean_io_u: 0.3883 - val_recall: 0.8851 - val_precision: 0.2353
# Epoch 11/100
# 1/1 [==============================] - 0s 303ms/step - loss: 1.0888 - mean_io_u: 0.4425 - recall: 0.9013 - precision: 0.1534 - val_loss: 1.0549 - val_mean_io_u: 0.3884 - val_recall: 0.8630 - val_precision: 0.2385
# Epoch 12/100
# 1/1 [==============================] - 0s 303ms/step - loss: 1.0568 - mean_io_u: 0.4417 - recall: 0.8904 - precision: 0.1564 - val_loss: 1.0249 - val_mean_io_u: 0.3883 - val_recall: 0.8373 - val_precision: 0.2502
# Epoch 13/100
# 1/1 [==============================] - 0s 313ms/step - loss: 1.0307 - mean_io_u: 0.4410 - recall: 0.8769 - precision: 0.1586 - val_loss: 1.0004 - val_mean_io_u: 0.3882 - val_recall: 0.8046 - val_precision: 0.2741
# Epoch 14/100
# 1/1 [==============================] - 0s 307ms/step - loss: 1.0084 - mean_io_u: 0.4404 - recall: 0.8613 - precision: 0.1622 - val_loss: 0.9812 - val_mean_io_u: 0.3881 - val_recall: 0.7750 - val_precision: 0.3035
# Epoch 15/100
# 1/1 [==============================] - 0s 303ms/step - loss: 0.9892 - mean_io_u: 0.4397 - recall: 0.8459 - precision: 0.1705 - val_loss: 0.9680 - val_mean_io_u: 0.3881 - val_recall: 0.7480 - val_precision: 0.3529
# Epoch 16/100
# 1/1 [==============================] - 0s 304ms/step - loss: 0.9751 - mean_io_u: 0.4393 - recall: 0.8317 - precision: 0.2000 - val_loss: 0.9592 - val_mean_io_u: 0.3880 - val_recall: 0.7215 - val_precision: 0.3857
# Epoch 17/100
# 1/1 [==============================] - 0s 311ms/step - loss: 0.9651 - mean_io_u: 0.4390 - recall: 0.8187 - precision: 0.2192 - val_loss: 0.9525 - val_mean_io_u: 0.3880 - val_recall: 0.6977 - val_precision: 0.4034
# Epoch 18/100
# 1/1 [==============================] - 0s 317ms/step - loss: 0.9569 - mean_io_u: 0.4385 - recall: 0.8057 - precision: 0.2342 - val_loss: 0.9469 - val_mean_io_u: 0.3878 - val_recall: 0.6678 - val_precision: 0.4100
# Epoch 19/100
# 1/1 [==============================] - 0s 312ms/step - loss: 0.9500 - mean_io_u: 0.4383 - recall: 0.7938 - precision: 0.2459 - val_loss: 0.9418 - val_mean_io_u: 0.3879 - val_recall: 0.6505 - val_precision: 0.4177
# Epoch 20/100
# 1/1 [==============================] - 0s 315ms/step - loss: 0.9438 - mean_io_u: 0.4380 - recall: 0.7828 - precision: 0.2541 - val_loss: 0.9370 - val_mean_io_u: 0.3879 - val_recall: 0.6284 - val_precision: 0.4187
# Epoch 21/100
# 1/1 [==============================] - 0s 301ms/step - loss: 0.9380 - mean_io_u: 0.4377 - recall: 0.7724 - precision: 0.2606 - val_loss: 0.9324 - val_mean_io_u: 0.3878 - val_recall: 0.6083 - val_precision: 0.4176
# Epoch 22/100
# 1/1 [==============================] - 0s 311ms/step - loss: 0.9325 - mean_io_u: 0.4374 - recall: 0.7634 - precision: 0.2664 - val_loss: 0.9278 - val_mean_io_u: 0.3878 - val_recall: 0.5940 - val_precision: 0.4210
# Epoch 23/100
# 1/1 [==============================] - 0s 305ms/step - loss: 0.9272 - mean_io_u: 0.4369 - recall: 0.7554 - precision: 0.2715 - val_loss: 0.9235 - val_mean_io_u: 0.3878 - val_recall: 0.5769 - val_precision: 0.4204
# Epoch 24/100
# 1/1 [==============================] - 0s 297ms/step - loss: 0.9222 - mean_io_u: 0.4366 - recall: 0.7480 - precision: 0.2763 - val_loss: 0.9192 - val_mean_io_u: 0.3878 - val_recall: 0.5636 - val_precision: 0.4194
# Epoch 25/100
# 1/1 [==============================] - 0s 309ms/step - loss: 0.9174 - mean_io_u: 0.4362 - recall: 0.7407 - precision: 0.2813 - val_loss: 0.9150 - val_mean_io_u: 0.3878 - val_recall: 0.5490 - val_precision: 0.4182
# Epoch 26/100
# 1/1 [==============================] - 0s 305ms/step - loss: 0.9128 - mean_io_u: 0.4358 - recall: 0.7345 - precision: 0.2861 - val_loss: 0.9109 - val_mean_io_u: 0.3877 - val_recall: 0.5357 - val_precision: 0.4180
# Epoch 27/100
# 1/1 [==============================] - 0s 308ms/step - loss: 0.9083 - mean_io_u: 0.4354 - recall: 0.7283 - precision: 0.2908 - val_loss: 0.9069 - val_mean_io_u: 0.3876 - val_recall: 0.5257 - val_precision: 0.4178
# Epoch 28/100
# 1/1 [==============================] - 0s 292ms/step - loss: 0.9040 - mean_io_u: 0.4351 - recall: 0.7222 - precision: 0.2955 - val_loss: 0.9030 - val_mean_io_u: 0.3875 - val_recall: 0.5169 - val_precision: 0.4177
# Epoch 29/100
# 1/1 [==============================] - 0s 303ms/step - loss: 0.8998 - mean_io_u: 0.4348 - recall: 0.7176 - precision: 0.3000 - val_loss: 0.8991 - val_mean_io_u: 0.3874 - val_recall: 0.5067 - val_precision: 0.4164
# Epoch 30/100
# 1/1 [==============================] - 0s 304ms/step - loss: 0.8956 - mean_io_u: 0.4345 - recall: 0.7135 - precision: 0.3043 - val_loss: 0.8953 - val_mean_io_u: 0.3872 - val_recall: 0.5002 - val_precision: 0.4164
# Epoch 31/100
# 1/1 [==============================] - 0s 302ms/step - loss: 0.8916 - mean_io_u: 0.4342 - recall: 0.7086 - precision: 0.3086 - val_loss: 0.8915 - val_mean_io_u: 0.3872 - val_recall: 0.4908 - val_precision: 0.4156
# Epoch 32/100
# 1/1 [==============================] - 0s 306ms/step - loss: 0.8876 - mean_io_u: 0.4341 - recall: 0.7035 - precision: 0.3128 - val_loss: 0.8878 - val_mean_io_u: 0.3870 - val_recall: 0.4831 - val_precision: 0.4138
# Epoch 33/100
# 1/1 [==============================] - 0s 307ms/step - loss: 0.8836 - mean_io_u: 0.4339 - recall: 0.6986 - precision: 0.3167 - val_loss: 0.8841 - val_mean_io_u: 0.3870 - val_recall: 0.4743 - val_precision: 0.4126
# Epoch 34/100
# 1/1 [==============================] - 0s 306ms/step - loss: 0.8798 - mean_io_u: 0.4336 - recall: 0.6934 - precision: 0.3204 - val_loss: 0.8805 - val_mean_io_u: 0.3870 - val_recall: 0.4643 - val_precision: 0.4102
# Epoch 35/100
# 1/1 [==============================] - 0s 310ms/step - loss: 0.8760 - mean_io_u: 0.4333 - recall: 0.6884 - precision: 0.3242 - val_loss: 0.8768 - val_mean_io_u: 0.3870 - val_recall: 0.4608 - val_precision: 0.4110
# Epoch 36/100
# 1/1 [==============================] - 0s 311ms/step - loss: 0.8722 - mean_io_u: 0.4330 - recall: 0.6833 - precision: 0.3275 - val_loss: 0.8733 - val_mean_io_u: 0.3869 - val_recall: 0.4549 - val_precision: 0.4098
# Epoch 37/100
# 1/1 [==============================] - 0s 315ms/step - loss: 0.8685 - mean_io_u: 0.4327 - recall: 0.6775 - precision: 0.3302 - val_loss: 0.8697 - val_mean_io_u: 0.3869 - val_recall: 0.4503 - val_precision: 0.4103
# Epoch 38/100
# 1/1 [==============================] - 0s 305ms/step - loss: 0.8648 - mean_io_u: 0.4326 - recall: 0.6732 - precision: 0.3337 - val_loss: 0.8662 - val_mean_io_u: 0.3869 - val_recall: 0.4436 - val_precision: 0.4087
# Epoch 39/100
# 1/1 [==============================] - 0s 302ms/step - loss: 0.8612 - mean_io_u: 0.4324 - recall: 0.6689 - precision: 0.3369 - val_loss: 0.8628 - val_mean_io_u: 0.3868 - val_recall: 0.4370 - val_precision: 0.4077
# Epoch 40/100
# 1/1 [==============================] - 0s 297ms/step - loss: 0.8577 - mean_io_u: 0.4322 - recall: 0.6647 - precision: 0.3399 - val_loss: 0.8594 - val_mean_io_u: 0.3868 - val_recall: 0.4301 - val_precision: 0.4064
# Epoch 41/100
# 1/1 [==============================] - 0s 297ms/step - loss: 0.8542 - mean_io_u: 0.4321 - recall: 0.6593 - precision: 0.3420 - val_loss: 0.8560 - val_mean_io_u: 0.3868 - val_recall: 0.4240 - val_precision: 0.4050
# Epoch 42/100
# 1/1 [==============================] - 0s 307ms/step - loss: 0.8507 - mean_io_u: 0.4319 - recall: 0.6545 - precision: 0.3439 - val_loss: 0.8527 - val_mean_io_u: 0.3868 - val_recall: 0.4177 - val_precision: 0.4024
# Epoch 43/100
# 1/1 [==============================] - 0s 299ms/step - loss: 0.8472 - mean_io_u: 0.4316 - recall: 0.6493 - precision: 0.3449 - val_loss: 0.8494 - val_mean_io_u: 0.3868 - val_recall: 0.4120 - val_precision: 0.3994
# Epoch 44/100
# 1/1 [==============================] - 0s 308ms/step - loss: 0.8437 - mean_io_u: 0.4314 - recall: 0.6439 - precision: 0.3451 - val_loss: 0.8461 - val_mean_io_u: 0.3868 - val_recall: 0.4091 - val_precision: 0.3983
# Epoch 45/100
# 1/1 [==============================] - 0s 310ms/step - loss: 0.8403 - mean_io_u: 0.4312 - recall: 0.6390 - precision: 0.3449 - val_loss: 0.8429 - val_mean_io_u: 0.3868 - val_recall: 0.4043 - val_precision: 0.3916
# Epoch 46/100
# 1/1 [==============================] - 0s 312ms/step - loss: 0.8368 - mean_io_u: 0.4310 - recall: 0.6342 - precision: 0.3425 - val_loss: 0.8396 - val_mean_io_u: 0.3868 - val_recall: 0.4000 - val_precision: 0.3814
# Epoch 47/100
# 1/1 [==============================] - 0s 309ms/step - loss: 0.8334 - mean_io_u: 0.4308 - recall: 0.6297 - precision: 0.3371 - val_loss: 0.8364 - val_mean_io_u: 0.3868 - val_recall: 0.3934 - val_precision: 0.3657
# Epoch 48/100
# 1/1 [==============================] - 0s 295ms/step - loss: 0.8301 - mean_io_u: 0.4307 - recall: 0.6240 - precision: 0.3287 - val_loss: 0.8333 - val_mean_io_u: 0.3868 - val_recall: 0.3902 - val_precision: 0.3421
# Epoch 49/100
# 1/1 [==============================] - 0s 300ms/step - loss: 0.8269 - mean_io_u: 0.4305 - recall: 0.6186 - precision: 0.3190 - val_loss: 0.8304 - val_mean_io_u: 0.3868 - val_recall: 0.3860 - val_precision: 0.3181
# Epoch 50/100
# 1/1 [==============================] - 0s 308ms/step - loss: 0.8240 - mean_io_u: 0.4303 - recall: 0.6134 - precision: 0.3102 - val_loss: 0.8275 - val_mean_io_u: 0.3868 - val_recall: 0.3822 - val_precision: 0.3051
# Epoch 51/100
# 1/1 [==============================] - 0s 296ms/step - loss: 0.8211 - mean_io_u: 0.4301 - recall: 0.6090 - precision: 0.3057 - val_loss: 0.8245 - val_mean_io_u: 0.3868 - val_recall: 0.3794 - val_precision: 0.3054
# Epoch 52/100
# 1/1 [==============================] - 0s 304ms/step - loss: 0.8180 - mean_io_u: 0.4299 - recall: 0.6039 - precision: 0.3055 - val_loss: 0.8213 - val_mean_io_u: 0.3868 - val_recall: 0.3760 - val_precision: 0.3106
# Epoch 53/100
# 1/1 [==============================] - 0s 302ms/step - loss: 0.8148 - mean_io_u: 0.4298 - recall: 0.5993 - precision: 0.3085 - val_loss: 0.8182 - val_mean_io_u: 0.3868 - val_recall: 0.3735 - val_precision: 0.3203
# Epoch 54/100
# 1/1 [==============================] - 0s 307ms/step - loss: 0.8116 - mean_io_u: 0.4297 - recall: 0.5959 - precision: 0.3136 - val_loss: 0.8151 - val_mean_io_u: 0.3868 - val_recall: 0.3709 - val_precision: 0.3304
# Epoch 55/100
# 1/1 [==============================] - 0s 293ms/step - loss: 0.8086 - mean_io_u: 0.4295 - recall: 0.5925 - precision: 0.3191 - val_loss: 0.8121 - val_mean_io_u: 0.3868 - val_recall: 0.3683 - val_precision: 0.3382
# Epoch 56/100
# 1/1 [==============================] - 0s 307ms/step - loss: 0.8056 - mean_io_u: 0.4294 - recall: 0.5891 - precision: 0.3236 - val_loss: 0.8091 - val_mean_io_u: 0.3868 - val_recall: 0.3659 - val_precision: 0.3422
# Epoch 57/100
# 1/1 [==============================] - 0s 300ms/step - loss: 0.8027 - mean_io_u: 0.4293 - recall: 0.5858 - precision: 0.3271 - val_loss: 0.8062 - val_mean_io_u: 0.3868 - val_recall: 0.3640 - val_precision: 0.3452
# Epoch 58/100
# 1/1 [==============================] - 0s 303ms/step - loss: 0.7998 - mean_io_u: 0.4293 - recall: 0.5817 - precision: 0.3287 - val_loss: 0.8033 - val_mean_io_u: 0.3868 - val_recall: 0.3616 - val_precision: 0.3452
# Epoch 59/100
# 1/1 [==============================] - 0s 298ms/step - loss: 0.7969 - mean_io_u: 0.4292 - recall: 0.5778 - precision: 0.3287 - val_loss: 0.8003 - val_mean_io_u: 0.3868 - val_recall: 0.3580 - val_precision: 0.3407
# Epoch 60/100
# 1/1 [==============================] - 0s 292ms/step - loss: 0.7941 - mean_io_u: 0.4292 - recall: 0.5731 - precision: 0.3273 - val_loss: 0.7974 - val_mean_io_u: 0.3868 - val_recall: 0.3539 - val_precision: 0.3340
# Epoch 61/100
# 1/1 [==============================] - 0s 297ms/step - loss: 0.7912 - mean_io_u: 0.4290 - recall: 0.5686 - precision: 0.3248 - val_loss: 0.7945 - val_mean_io_u: 0.3868 - val_recall: 0.3505 - val_precision: 0.3260
# Epoch 62/100
# 1/1 [==============================] - 0s 296ms/step - loss: 0.7884 - mean_io_u: 0.4289 - recall: 0.5637 - precision: 0.3212 - val_loss: 0.7917 - val_mean_io_u: 0.3868 - val_recall: 0.3483 - val_precision: 0.3178
# Epoch 63/100
# 1/1 [==============================] - 0s 298ms/step - loss: 0.7856 - mean_io_u: 0.4289 - recall: 0.5586 - precision: 0.3166 - val_loss: 0.7888 - val_mean_io_u: 0.3868 - val_recall: 0.3449 - val_precision: 0.3094
# Epoch 64/100
# 1/1 [==============================] - 0s 304ms/step - loss: 0.7829 - mean_io_u: 0.4288 - recall: 0.5531 - precision: 0.3123 - val_loss: 0.7860 - val_mean_io_u: 0.3868 - val_recall: 0.3418 - val_precision: 0.3016
# Epoch 65/100
# 1/1 [==============================] - 0s 299ms/step - loss: 0.7802 - mean_io_u: 0.4288 - recall: 0.5477 - precision: 0.3082 - val_loss: 0.7832 - val_mean_io_u: 0.3868 - val_recall: 0.3399 - val_precision: 0.2958
# Epoch 66/100
# 1/1 [==============================] - 0s 312ms/step - loss: 0.7774 - mean_io_u: 0.4288 - recall: 0.5426 - precision: 0.3050 - val_loss: 0.7804 - val_mean_io_u: 0.3868 - val_recall: 0.3365 - val_precision: 0.2927
# Epoch 67/100
# 1/1 [==============================] - 0s 302ms/step - loss: 0.7748 - mean_io_u: 0.4287 - recall: 0.5378 - precision: 0.3033 - val_loss: 0.7776 - val_mean_io_u: 0.3868 - val_recall: 0.3327 - val_precision: 0.2922
# Epoch 68/100
# 1/1 [==============================] - 0s 299ms/step - loss: 0.7721 - mean_io_u: 0.4286 - recall: 0.5335 - precision: 0.3031 - val_loss: 0.7748 - val_mean_io_u: 0.3868 - val_recall: 0.3296 - val_precision: 0.2932
# Epoch 69/100
# 1/1 [==============================] - 0s 312ms/step - loss: 0.7693 - mean_io_u: 0.4285 - recall: 0.5290 - precision: 0.3033 - val_loss: 0.7720 - val_mean_io_u: 0.3868 - val_recall: 0.3255 - val_precision: 0.2935
# Epoch 70/100
# 1/1 [==============================] - 0s 306ms/step - loss: 0.7666 - mean_io_u: 0.4284 - recall: 0.5247 - precision: 0.3037 - val_loss: 0.7693 - val_mean_io_u: 0.3868 - val_recall: 0.3239 - val_precision: 0.2954
# Epoch 71/100
# 1/1 [==============================] - 0s 309ms/step - loss: 0.7639 - mean_io_u: 0.4283 - recall: 0.5186 - precision: 0.3033 - val_loss: 0.7666 - val_mean_io_u: 0.3868 - val_recall: 0.3213 - val_precision: 0.2949
# Epoch 72/100
# 1/1 [==============================] - 0s 307ms/step - loss: 0.7613 - mean_io_u: 0.4282 - recall: 0.5134 - precision: 0.3029 - val_loss: 0.7641 - val_mean_io_u: 0.3868 - val_recall: 0.3174 - val_precision: 0.2947
# Epoch 73/100
# 1/1 [==============================] - 0s 306ms/step - loss: 0.7588 - mean_io_u: 0.4281 - recall: 0.5088 - precision: 0.3029 - val_loss: 0.7618 - val_mean_io_u: 0.3868 - val_recall: 0.3141 - val_precision: 0.2949
# Epoch 74/100
# 1/1 [==============================] - 0s 309ms/step - loss: 0.7565 - mean_io_u: 0.4280 - recall: 0.5042 - precision: 0.3031 - val_loss: 0.7596 - val_mean_io_u: 0.3868 - val_recall: 0.3110 - val_precision: 0.2968
# Epoch 75/100
# 1/1 [==============================] - 0s 316ms/step - loss: 0.7543 - mean_io_u: 0.4279 - recall: 0.5001 - precision: 0.3032 - val_loss: 0.7575 - val_mean_io_u: 0.3868 - val_recall: 0.3071 - val_precision: 0.2968
# Epoch 76/100
# 1/1 [==============================] - 0s 309ms/step - loss: 0.7521 - mean_io_u: 0.4278 - recall: 0.4960 - precision: 0.3037 - val_loss: 0.7555 - val_mean_io_u: 0.3868 - val_recall: 0.3059 - val_precision: 0.3000
# Epoch 77/100
# 1/1 [==============================] - 0s 313ms/step - loss: 0.7501 - mean_io_u: 0.4278 - recall: 0.4914 - precision: 0.3043 - val_loss: 0.7536 - val_mean_io_u: 0.3868 - val_recall: 0.3005 - val_precision: 0.3003
# Epoch 78/100
# 1/1 [==============================] - 0s 301ms/step - loss: 0.7481 - mean_io_u: 0.4278 - recall: 0.4867 - precision: 0.3046 - val_loss: 0.7517 - val_mean_io_u: 0.3868 - val_recall: 0.2970 - val_precision: 0.3003
# Epoch 79/100
# 1/1 [==============================] - 0s 304ms/step - loss: 0.7462 - mean_io_u: 0.4278 - recall: 0.4838 - precision: 0.3052 - val_loss: 0.7499 - val_mean_io_u: 0.3868 - val_recall: 0.2954 - val_precision: 0.3008
# Epoch 80/100
# 1/1 [==============================] - 0s 310ms/step - loss: 0.7443 - mean_io_u: 0.4277 - recall: 0.4789 - precision: 0.3043 - val_loss: 0.7481 - val_mean_io_u: 0.3868 - val_recall: 0.2930 - val_precision: 0.3008
# Epoch 81/100
# 1/1 [==============================] - 0s 309ms/step - loss: 0.7425 - mean_io_u: 0.4277 - recall: 0.4748 - precision: 0.3035 - val_loss: 0.7463 - val_mean_io_u: 0.3868 - val_recall: 0.2908 - val_precision: 0.2996
# Epoch 82/100
# 1/1 [==============================] - 0s 300ms/step - loss: 0.7408 - mean_io_u: 0.4276 - recall: 0.4705 - precision: 0.3021 - val_loss: 0.7446 - val_mean_io_u: 0.3868 - val_recall: 0.2880 - val_precision: 0.2984
# Epoch 83/100
# 1/1 [==============================] - 0s 316ms/step - loss: 0.7390 - mean_io_u: 0.4275 - recall: 0.4658 - precision: 0.3007 - val_loss: 0.7429 - val_mean_io_u: 0.3868 - val_recall: 0.2849 - val_precision: 0.2960
# Epoch 84/100
# 1/1 [==============================] - 0s 310ms/step - loss: 0.7373 - mean_io_u: 0.4275 - recall: 0.4609 - precision: 0.2990 - val_loss: 0.7413 - val_mean_io_u: 0.3868 - val_recall: 0.2834 - val_precision: 0.2941
# Epoch 85/100
# 1/1 [==============================] - 0s 310ms/step - loss: 0.7356 - mean_io_u: 0.4274 - recall: 0.4562 - precision: 0.2970 - val_loss: 0.7397 - val_mean_io_u: 0.3868 - val_recall: 0.2811 - val_precision: 0.2919
# Epoch 86/100
# 1/1 [==============================] - 0s 299ms/step - loss: 0.7340 - mean_io_u: 0.4274 - recall: 0.4513 - precision: 0.2944 - val_loss: 0.7381 - val_mean_io_u: 0.3868 - val_recall: 0.2792 - val_precision: 0.2897
# Epoch 87/100
# 1/1 [==============================] - 0s 311ms/step - loss: 0.7324 - mean_io_u: 0.4274 - recall: 0.4461 - precision: 0.2920 - val_loss: 0.7365 - val_mean_io_u: 0.3868 - val_recall: 0.2763 - val_precision: 0.2864
# Epoch 88/100
# 1/1 [==============================] - 0s 301ms/step - loss: 0.7308 - mean_io_u: 0.4273 - recall: 0.4411 - precision: 0.2894 - val_loss: 0.7350 - val_mean_io_u: 0.3868 - val_recall: 0.2722 - val_precision: 0.2836
# Epoch 89/100
# 1/1 [==============================] - 0s 309ms/step - loss: 0.7292 - mean_io_u: 0.4273 - recall: 0.4367 - precision: 0.2877 - val_loss: 0.7335 - val_mean_io_u: 0.3868 - val_recall: 0.2691 - val_precision: 0.2818
# Epoch 90/100
# 1/1 [==============================] - 0s 318ms/step - loss: 0.7277 - mean_io_u: 0.4272 - recall: 0.4318 - precision: 0.2863 - val_loss: 0.7321 - val_mean_io_u: 0.3868 - val_recall: 0.2665 - val_precision: 0.2815
# Epoch 91/100
# 1/1 [==============================] - 0s 310ms/step - loss: 0.7262 - mean_io_u: 0.4272 - recall: 0.4281 - precision: 0.2859 - val_loss: 0.7307 - val_mean_io_u: 0.3868 - val_recall: 0.2645 - val_precision: 0.2834
# Epoch 92/100
# 1/1 [==============================] - 0s 306ms/step - loss: 0.7247 - mean_io_u: 0.4272 - recall: 0.4240 - precision: 0.2859 - val_loss: 0.7293 - val_mean_io_u: 0.3868 - val_recall: 0.2621 - val_precision: 0.2840
# Epoch 93/100
# 1/1 [==============================] - 0s 309ms/step - loss: 0.7233 - mean_io_u: 0.4271 - recall: 0.4195 - precision: 0.2857 - val_loss: 0.7280 - val_mean_io_u: 0.3868 - val_recall: 0.2602 - val_precision: 0.2839
# Epoch 94/100
# 1/1 [==============================] - 0s 300ms/step - loss: 0.7219 - mean_io_u: 0.4271 - recall: 0.4147 - precision: 0.2846 - val_loss: 0.7266 - val_mean_io_u: 0.3868 - val_recall: 0.2572 - val_precision: 0.2814
# Epoch 95/100
# 1/1 [==============================] - 0s 307ms/step - loss: 0.7205 - mean_io_u: 0.4271 - recall: 0.4111 - precision: 0.2828 - val_loss: 0.7252 - val_mean_io_u: 0.3868 - val_recall: 0.2543 - val_precision: 0.2769
# Epoch 96/100
# 1/1 [==============================] - 0s 300ms/step - loss: 0.7191 - mean_io_u: 0.4271 - recall: 0.4077 - precision: 0.2794 - val_loss: 0.7238 - val_mean_io_u: 0.3868 - val_recall: 0.2498 - val_precision: 0.2698
# Epoch 97/100
# 1/1 [==============================] - 0s 315ms/step - loss: 0.7177 - mean_io_u: 0.4270 - recall: 0.4039 - precision: 0.2742 - val_loss: 0.7223 - val_mean_io_u: 0.3868 - val_recall: 0.2479 - val_precision: 0.2636
# Epoch 98/100
# 1/1 [==============================] - 0s 299ms/step - loss: 0.7163 - mean_io_u: 0.4270 - recall: 0.3995 - precision: 0.2678 - val_loss: 0.7208 - val_mean_io_u: 0.3868 - val_recall: 0.2452 - val_precision: 0.2552
# Epoch 99/100
# 1/1 [==============================] - 0s 304ms/step - loss: 0.7148 - mean_io_u: 0.4270 - recall: 0.3956 - precision: 0.2611 - val_loss: 0.7192 - val_mean_io_u: 0.3868 - val_recall: 0.2419 - val_precision: 0.2481
# Epoch 100/100
# 1/1 [==============================] - 0s 306ms/step - loss: 0.7134 - mean_io_u: 0.4270 - recall: 0.3923 - precision: 0.2544 - val_loss: 0.7176 - val_mean_io_u: 0.3868 - val_recall: 0.2394 - val_precision: 0.2433

# %% [markdown]
# ### Apply network to (unseen) test data

# %%
predicted_masks = model.predict(images_test, verbose=1)
predicted_masks = predicted_masks > 0.5
# Out:
# 1/1 [==============================] - 0s 235ms/step

# %%
# Visualise some results
def plot_predictions(
    raw_images,
    predictions,
    ground_truth,
    num_to_plot=2,
    fig_size=(15, 15),
    axes_pad=0.1,
):
    """
    Compare predicted & actual mask images

    :param raw_images: Array of raw data images
    :param predictions: Array of prediction mask images
    :param ground_truth: Array of ground truth mask images
    :param num_to_plot: How many random images to plot
    :param fig_size: Tuple of overall figure size
    :param axes_pad: Seperation of individual images
    """

    idx_to_plot = tuple(random.sample(range(0, len(raw_images)), num_to_plot))

    raw_images = raw_images[tuple([idx_to_plot])]
    predictions = np.squeeze(predictions)[tuple([idx_to_plot])]
    ground_truth = np.squeeze(ground_truth)[tuple([idx_to_plot])]

    fig = plt.figure(figsize=fig_size)
    grid = ImageGrid(
        fig,
        111,
        nrows_ncols=(num_to_plot, 3),
        axes_pad=axes_pad,
    )

    images = []
    for a, b, c in zip(raw_images, predictions, ground_truth):
        images.extend([a, b, c])

    for ax, im in zip(grid, images):
        ax.imshow(im)
        ax.axis("off")

    grid[0].title.set_text("Raw data")
    grid[1].title.set_text("Network prediction")
    grid[2].title.set_text("Ground truth")

# %%
plot_predictions(images_test, predicted_masks, masks_test, num_to_plot=5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_167185/3555514682.py in <module>
# ----> 1 plot_predictions(images_test, predicted_masks, masks_test, num_to_plot=5)
#
# /tmp/ipykernel_167185/252569921.py in plot_predictions(raw_images, predictions, ground_truth, num_to_plot, fig_size, axes_pad)
#      19     """
#      20
# ---> 21     idx_to_plot = tuple(random.sample(range(0, len(raw_images)), num_to_plot))
#      22
#      23     raw_images = raw_images[tuple([idx_to_plot])]
#
# ~/.conda/envs/dl-icr/lib/python3.9/random.py in sample(self, population, k, counts)
#     447         randbelow = self._randbelow
#     448         if not 0 <= k <= n:
# --> 449             raise ValueError("Sample larger than population or is negative")
#     450         result = [None] * k
#     451         setsize = 21        # size of a small set minus size of an empty list
#
# ValueError: Sample larger than population or is negative

# %% [markdown]
# ## Limitations
# * Segmentation not perfect, lots of ways to improve (more training, augmentation, better network, adjust hyperparameters etc.)
# * We segmented *all* cells, and not *each* cell. We could further these masks (e.g. by using a watershed algorithm), or use an alternative, object detection network (e.g. [Mask R-CNN](https://arxiv.org/abs/1703.06870))

# %% [markdown]
# ## Image segmentation using U-Nets (Data Science Bowl 2018)
#
# #### Segmentation of nuclei in microscopy images
# The segmentation of nuclei in microscopy images is a common task in many workflows. Most traditional image processing methods are created for one specific type of image, and perform poorly on others.
#
# The aim is to develop a general-purpose algorithm to segment cell nuclei from any type of microscopy images.
#
# <img src="images/nuclei_image_types.png" style="width: 600px;"/>
#
# ---
#
# We will use a U-Net Convolutional Neural Network to perform this task. This notebook is adapted from [Keras U-Net starter by Kjetil Åmdal-Sævik](https://www.kaggle.com/keegil/keras-u-net-starter-lb-0-277?scriptVersionId=2164855) ([Licensed under the Apache License, Version 2.0](http://www.apache.org/licenses/LICENSE-2.0))
#
#
# **For more information, see the original publication about the 2018 Data Science Bowl:**
#
# [Caicedo, J.C., Goodman, A., Karhohs, K.W. et al.
# Nucleus segmentation across imaging experiments: the 2018 Data Science Bowl.
# Nat Methods 16, 1247–1253 (2019)](https://doi.org/10.1038/s41592-019-0612-7)
#
# We will be using some data from the original challenge (hosted at [https://www.kaggle.com/c/data-science-bowl-2018](https://www.kaggle.com/c/data-science-bowl-2018) (account required), and also from the [Broad Institute](https://bbbc.broadinstitute.org/BBBC038)). A copy is stored at **INSERT HPC LOCATION**

# %% [markdown]
# ### We begin by loading and visualising some of the data

# %%
import os
import numpy as np

from pathlib import Path
from tqdm import tqdm
from skimage.io import imread
from skimage.transform import resize

# Where the data is stored
path_data = "/data/scratch/DCO/DIGOPS/SCIENCOM/atyson01/datasets/data-science-bowl-2018/stage1_train/"

DEBUG = False  # Set to True to only load a fraction of the raw data

def load_images(
    path_data, image_width=128, image_height=128, num_channels=3, debug=False
):
    """
    Load all images into memory, and do some preprocessing (e.g. rescaling)

    :param path_data: Location of the data on disk (pathlib object)
    :param image_width: Image width in pixels for resizing
    :param image_height: Image height in pixels for resizing
    :param num_channels: Final number of channels required

    :return images, masks: Numpy array of images, and segmentation masks
    """

    path_data = Path(path_data)

    filenames = next(os.walk(path_data))[1]
    if debug:
        filenames = filenames[:20]

    images = np.zeros(
        (len(filenames), image_height, image_width, num_channels),
        dtype=np.uint8,
    )
    masks = np.zeros(
        (len(filenames), image_height, image_width, 1), dtype=np.bool
    )

    for n, image_id in tqdm(enumerate(filenames), total=len(filenames)):
        img = imread(path_data / image_id / "images" / (image_id + ".png"))[
            :, :, :num_channels
        ]
        img = resize(
            img,
            (image_height, image_width),
            mode="constant",
            preserve_range=True,
        )
        images[n] = img
        mask = np.zeros((image_height, image_width, 1), dtype=np.bool)

        mask_dir = path_data / image_id / "masks"
        for mask_file in next(os.walk(mask_dir))[2]:
            mask_ = imread(mask_dir / mask_file)
            mask_ = np.expand_dims(
                resize(
                    mask_,
                    (image_height, image_width),
                    mode="constant",
                    preserve_range=True,
                ),
                axis=-1,
            )
            mask = np.maximum(mask, mask_)
        masks[n] = mask
    return images, masks

# %%
images, masks = load_images(path_data, debug=DEBUG)
# Out:
# 100%|██████████| 20/20 [00:06<00:00,  2.96it/s]

# %%
# Visualise some raw data and segmentation masks
import random

import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid


def plot_raw_data(
    raw_images, masks, num_to_plot=2, fig_size=(10, 10), axes_pad=0.1
):
    """
    Plot raw data

    :param raw_images: Array of raw data images
    :param masks: Array of mask images
    :param num_to_plot: How many random images to plot
    :param fig_size: Tuple of overall figure size
    :param axes_pad: Seperation of individual images
    """

    idx_to_plot = tuple(random.sample(range(0, len(raw_images)), num_to_plot))

    raw_images = raw_images[tuple([idx_to_plot])]
    masks = np.squeeze(masks)[tuple([idx_to_plot])]

    fig = plt.figure(figsize=fig_size)
    grid = ImageGrid(
        fig,
        111,
        nrows_ncols=(num_to_plot, 2),
        axes_pad=axes_pad,
    )

    images = []
    for a, b in zip(raw_images, masks):
        images.extend([a, b])

    for ax, im in zip(grid, images):
        ax.imshow(im)
        ax.axis("off")

    grid[0].title.set_text("Raw data")
    grid[1].title.set_text("Segmentation masks")


plot_raw_data(images, masks, num_to_plot=5)

# %% [markdown]
# ### Now we'll build a model to segment these images
#
# We'll be using the popular [U-Net architecture](https://arxiv.org/abs/1505.04597)
#
# <img src="images/unet.png" style="width: 400px;"/>

# %%
from keras.models import Model
from keras.layers import Input
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.preprocessing.image import ImageDataGenerator


def build_unet(image_width=128, image_height=128, num_channels=3):
    inputs = Input((image_height, image_width, num_channels))
    s = Lambda(lambda x: x / 255)(inputs)

    c1 = Conv2D(8, (3, 3), activation="relu", padding="same")(inputs)
    c1 = Conv2D(8, (3, 3), activation="relu", padding="same")(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(16, (3, 3), activation="relu", padding="same")(p1)
    c2 = Conv2D(16, (3, 3), activation="relu", padding="same")(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(32, (3, 3), activation="relu", padding="same")(p2)
    c3 = Conv2D(32, (3, 3), activation="relu", padding="same")(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(64, (3, 3), activation="relu", padding="same")(p3)
    c4 = Conv2D(64, (3, 3), activation="relu", padding="same")(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)

    c5 = Conv2D(128, (3, 3), activation="relu", padding="same")(p4)
    c5 = Conv2D(128, (3, 3), activation="relu", padding="same")(c5)

    u6 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding="same")(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(64, (3, 3), activation="relu", padding="same")(u6)
    c6 = Conv2D(64, (3, 3), activation="relu", padding="same")(c6)

    u7 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding="same")(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(32, (3, 3), activation="relu", padding="same")(u7)
    c7 = Conv2D(32, (3, 3), activation="relu", padding="same")(c7)

    u8 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding="same")(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(16, (3, 3), activation="relu", padding="same")(u8)
    c8 = Conv2D(16, (3, 3), activation="relu", padding="same")(c8)

    u9 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding="same")(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(8, (3, 3), activation="relu", padding="same")(u9)
    c9 = Conv2D(8, (3, 3), activation="relu", padding="same")(c9)

    outputs = Conv2D(1, (1, 1), activation="sigmoid")(c9)
    model = Model(inputs=[inputs], outputs=[outputs])
    return model
# Out:
# 2022-01-25 11:05:17.059209: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-01-25 11:05:17.059234: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
import tensorflow as tf

model = build_unet()
model.compile(
    loss="binary_crossentropy",
    optimizer=tf.keras.optimizers.Adam(0.0001),
    metrics=[
        tf.keras.metrics.MeanIoU(num_classes=2),
        tf.keras.metrics.Recall(),
        tf.keras.metrics.Precision(),
    ],
)
# Out:
# 2022-01-25 11:05:19.928684: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-01-25 11:05:19.928786: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-01-25 11:05:19.928847: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-01-25 11:05:19.928910: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-01-25 11:05:19.928967: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-01-25 11:05:19.929037: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-01-25 11:05:19.929090: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-01-25 11:05:19.929148: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-01-25 11:05:19.929158: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-01-25 11:05:19.929333: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Split the dataset into a train (80%) and test (20%) fraction

# %%
from sklearn.model_selection import train_test_split

test_fraction = 0.2

(images_train, images_test, masks_train, masks_test,) = train_test_split(
    images,
    masks,
    test_size=test_fraction,
)

# %% [markdown]
# ### Train the model

# %%
epochs = 100  # Number of iterations over the full dataset
batch_size = 32  # Number of samples per gradient update
validation_split = 0.1  # In addition to test dataset, use 10% of data to assess performance during training

model.fit(
    images_train,
    masks_train,
    validation_split=validation_split,
    batch_size=batch_size,
    epochs=epochs,
)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 10.0967 - mean_io_u: 0.3837 - recall: 0.9720 - precision: 0.1667 - val_loss: 1.1863 - val_mean_io_u: 0.4178 - val_recall: 0.9820 - val_precision: 0.1717
# Epoch 2/100
# 1/1 [==============================] - 0s 308ms/step - loss: 9.8769 - mean_io_u: 0.3817 - recall: 0.9699 - precision: 0.1665 - val_loss: 1.1701 - val_mean_io_u: 0.4172 - val_recall: 0.9813 - val_precision: 0.1716
# Epoch 3/100
# 1/1 [==============================] - 0s 309ms/step - loss: 9.6581 - mean_io_u: 0.3796 - recall: 0.9684 - precision: 0.1664 - val_loss: 1.1542 - val_mean_io_u: 0.4168 - val_recall: 0.9808 - val_precision: 0.1716
# Epoch 4/100
# 1/1 [==============================] - 0s 302ms/step - loss: 9.4403 - mean_io_u: 0.3773 - recall: 0.9662 - precision: 0.1663 - val_loss: 1.1386 - val_mean_io_u: 0.4166 - val_recall: 0.9799 - val_precision: 0.1715
# Epoch 5/100
# 1/1 [==============================] - 0s 310ms/step - loss: 9.2259 - mean_io_u: 0.3750 - recall: 0.9638 - precision: 0.1661 - val_loss: 1.1233 - val_mean_io_u: 0.4161 - val_recall: 0.9783 - val_precision: 0.1713
# Epoch 6/100
# 1/1 [==============================] - 0s 315ms/step - loss: 9.0179 - mean_io_u: 0.3731 - recall: 0.9617 - precision: 0.1660 - val_loss: 1.1084 - val_mean_io_u: 0.4159 - val_recall: 0.9762 - val_precision: 0.1710
# Epoch 7/100
# 1/1 [==============================] - 0s 302ms/step - loss: 8.8121 - mean_io_u: 0.3708 - recall: 0.9596 - precision: 0.1658 - val_loss: 1.0937 - val_mean_io_u: 0.4157 - val_recall: 0.9750 - val_precision: 0.1709
# Epoch 8/100
# 1/1 [==============================] - 0s 319ms/step - loss: 8.6082 - mean_io_u: 0.3687 - recall: 0.9568 - precision: 0.1655 - val_loss: 1.0792 - val_mean_io_u: 0.4151 - val_recall: 0.9743 - val_precision: 0.1708
# Epoch 9/100
# 1/1 [==============================] - 0s 309ms/step - loss: 8.4061 - mean_io_u: 0.3669 - recall: 0.9538 - precision: 0.1653 - val_loss: 1.0650 - val_mean_io_u: 0.4151 - val_recall: 0.9718 - val_precision: 0.1705
# Epoch 10/100
# 1/1 [==============================] - 0s 298ms/step - loss: 8.2058 - mean_io_u: 0.3649 - recall: 0.9510 - precision: 0.1651 - val_loss: 1.0510 - val_mean_io_u: 0.4150 - val_recall: 0.9702 - val_precision: 0.1704
# Epoch 11/100
# 1/1 [==============================] - 0s 312ms/step - loss: 8.0073 - mean_io_u: 0.3629 - recall: 0.9477 - precision: 0.1649 - val_loss: 1.0371 - val_mean_io_u: 0.4146 - val_recall: 0.9691 - val_precision: 0.1702
# Epoch 12/100
# 1/1 [==============================] - 0s 309ms/step - loss: 7.8106 - mean_io_u: 0.3610 - recall: 0.9442 - precision: 0.1646 - val_loss: 1.0234 - val_mean_io_u: 0.4145 - val_recall: 0.9675 - val_precision: 0.1701
# Epoch 13/100
# 1/1 [==============================] - 0s 316ms/step - loss: 7.6154 - mean_io_u: 0.3590 - recall: 0.9414 - precision: 0.1645 - val_loss: 1.0098 - val_mean_io_u: 0.4141 - val_recall: 0.9644 - val_precision: 0.1697
# Epoch 14/100
# 1/1 [==============================] - 0s 304ms/step - loss: 7.4217 - mean_io_u: 0.3573 - recall: 0.9384 - precision: 0.1644 - val_loss: 0.9962 - val_mean_io_u: 0.4139 - val_recall: 0.9621 - val_precision: 0.1695
# Epoch 15/100
# 1/1 [==============================] - 0s 301ms/step - loss: 7.2293 - mean_io_u: 0.3558 - recall: 0.9347 - precision: 0.1643 - val_loss: 0.9827 - val_mean_io_u: 0.4137 - val_recall: 0.9593 - val_precision: 0.1692
# Epoch 16/100
# 1/1 [==============================] - 0s 300ms/step - loss: 7.0379 - mean_io_u: 0.3543 - recall: 0.9313 - precision: 0.1642 - val_loss: 0.9691 - val_mean_io_u: 0.4136 - val_recall: 0.9561 - val_precision: 0.1688
# Epoch 17/100
# 1/1 [==============================] - 0s 310ms/step - loss: 6.8469 - mean_io_u: 0.3531 - recall: 0.9274 - precision: 0.1642 - val_loss: 0.9553 - val_mean_io_u: 0.4136 - val_recall: 0.9543 - val_precision: 0.1687
# Epoch 18/100
# 1/1 [==============================] - 0s 306ms/step - loss: 6.6563 - mean_io_u: 0.3517 - recall: 0.9231 - precision: 0.1641 - val_loss: 0.9414 - val_mean_io_u: 0.4135 - val_recall: 0.9510 - val_precision: 0.1684
# Epoch 19/100
# 1/1 [==============================] - 0s 313ms/step - loss: 6.4652 - mean_io_u: 0.3504 - recall: 0.9182 - precision: 0.1642 - val_loss: 0.9271 - val_mean_io_u: 0.4135 - val_recall: 0.9478 - val_precision: 0.1682
# Epoch 20/100
# 1/1 [==============================] - 0s 310ms/step - loss: 6.2723 - mean_io_u: 0.3491 - recall: 0.9131 - precision: 0.1645 - val_loss: 0.9123 - val_mean_io_u: 0.4135 - val_recall: 0.9434 - val_precision: 0.1681
# Epoch 21/100
# 1/1 [==============================] - 0s 308ms/step - loss: 6.0770 - mean_io_u: 0.3480 - recall: 0.9082 - precision: 0.1654 - val_loss: 0.8969 - val_mean_io_u: 0.4135 - val_recall: 0.9411 - val_precision: 0.1686
# Epoch 22/100
# 1/1 [==============================] - 0s 320ms/step - loss: 5.8781 - mean_io_u: 0.3468 - recall: 0.9030 - precision: 0.1670 - val_loss: 0.8805 - val_mean_io_u: 0.4135 - val_recall: 0.9372 - val_precision: 0.1694
# Epoch 23/100
# 1/1 [==============================] - 0s 304ms/step - loss: 5.6748 - mean_io_u: 0.3456 - recall: 0.8966 - precision: 0.1695 - val_loss: 0.8629 - val_mean_io_u: 0.4135 - val_recall: 0.9339 - val_precision: 0.1716
# Epoch 24/100
# 1/1 [==============================] - 0s 310ms/step - loss: 5.4664 - mean_io_u: 0.3445 - recall: 0.8890 - precision: 0.1732 - val_loss: 0.8432 - val_mean_io_u: 0.4135 - val_recall: 0.9286 - val_precision: 0.1755
# Epoch 25/100
# 1/1 [==============================] - 0s 292ms/step - loss: 5.2513 - mean_io_u: 0.3435 - recall: 0.8805 - precision: 0.1778 - val_loss: 0.8206 - val_mean_io_u: 0.4135 - val_recall: 0.9206 - val_precision: 0.1820
# Epoch 26/100
# 1/1 [==============================] - 0s 299ms/step - loss: 5.0272 - mean_io_u: 0.3425 - recall: 0.8695 - precision: 0.1829 - val_loss: 0.7948 - val_mean_io_u: 0.4135 - val_recall: 0.9109 - val_precision: 0.1939
# Epoch 27/100
# 1/1 [==============================] - 0s 306ms/step - loss: 4.7916 - mean_io_u: 0.3470 - recall: 0.8537 - precision: 0.1883 - val_loss: 0.7661 - val_mean_io_u: 0.4135 - val_recall: 0.8970 - val_precision: 0.2120
# Epoch 28/100
# 1/1 [==============================] - 0s 311ms/step - loss: 4.5434 - mean_io_u: 0.3640 - recall: 0.8312 - precision: 0.1946 - val_loss: 0.7360 - val_mean_io_u: 0.4135 - val_recall: 0.8746 - val_precision: 0.2308
# Epoch 29/100
# 1/1 [==============================] - 0s 315ms/step - loss: 4.2807 - mean_io_u: 0.3844 - recall: 0.8020 - precision: 0.2011 - val_loss: 0.7067 - val_mean_io_u: 0.4135 - val_recall: 0.8464 - val_precision: 0.2491
# Epoch 30/100
# 1/1 [==============================] - 0s 312ms/step - loss: 4.0016 - mean_io_u: 0.3965 - recall: 0.7649 - precision: 0.2044 - val_loss: 0.6818 - val_mean_io_u: 0.4135 - val_recall: 0.8095 - val_precision: 0.2638
# Epoch 31/100
# 1/1 [==============================] - 0s 304ms/step - loss: 3.7083 - mean_io_u: 0.4019 - recall: 0.7145 - precision: 0.2025 - val_loss: 0.6640 - val_mean_io_u: 0.4135 - val_recall: 0.7547 - val_precision: 0.2706
# Epoch 32/100
# 1/1 [==============================] - 0s 307ms/step - loss: 3.3907 - mean_io_u: 0.4037 - recall: 0.6501 - precision: 0.1958 - val_loss: 0.6572 - val_mean_io_u: 0.4135 - val_recall: 0.6772 - val_precision: 0.2651
# Epoch 33/100
# 1/1 [==============================] - 0s 320ms/step - loss: 3.0400 - mean_io_u: 0.4039 - recall: 0.5754 - precision: 0.1902 - val_loss: 0.6647 - val_mean_io_u: 0.4135 - val_recall: 0.5723 - val_precision: 0.2458
# Epoch 34/100
# 1/1 [==============================] - 0s 303ms/step - loss: 2.8011 - mean_io_u: 0.4035 - recall: 0.4995 - precision: 0.1926 - val_loss: 0.6841 - val_mean_io_u: 0.4135 - val_recall: 0.4903 - val_precision: 0.2292
# Epoch 35/100
# 1/1 [==============================] - 0s 306ms/step - loss: 2.7033 - mean_io_u: 0.4030 - recall: 0.4421 - precision: 0.1925 - val_loss: 0.7039 - val_mean_io_u: 0.4135 - val_recall: 0.4312 - val_precision: 0.2195
# Epoch 36/100
# 1/1 [==============================] - 0s 303ms/step - loss: 2.6565 - mean_io_u: 0.4025 - recall: 0.4018 - precision: 0.1951 - val_loss: 0.7127 - val_mean_io_u: 0.4135 - val_recall: 0.4000 - val_precision: 0.2201
# Epoch 37/100
# 1/1 [==============================] - 0s 302ms/step - loss: 2.6088 - mean_io_u: 0.4018 - recall: 0.3751 - precision: 0.1985 - val_loss: 0.7070 - val_mean_io_u: 0.4135 - val_recall: 0.3815 - val_precision: 0.2232
# Epoch 38/100
# 1/1 [==============================] - 0s 306ms/step - loss: 2.5252 - mean_io_u: 0.4008 - recall: 0.3603 - precision: 0.2040 - val_loss: 0.6906 - val_mean_io_u: 0.4135 - val_recall: 0.3744 - val_precision: 0.2302
# Epoch 39/100
# 1/1 [==============================] - 0s 303ms/step - loss: 2.4076 - mean_io_u: 0.4000 - recall: 0.3551 - precision: 0.2114 - val_loss: 0.6688 - val_mean_io_u: 0.4135 - val_recall: 0.3758 - val_precision: 0.2395
# Epoch 40/100
# 1/1 [==============================] - 0s 298ms/step - loss: 2.2700 - mean_io_u: 0.4013 - recall: 0.3556 - precision: 0.2182 - val_loss: 0.6462 - val_mean_io_u: 0.4135 - val_recall: 0.3838 - val_precision: 0.2498
# Epoch 41/100
# 1/1 [==============================] - 0s 304ms/step - loss: 2.1251 - mean_io_u: 0.4016 - recall: 0.3608 - precision: 0.2242 - val_loss: 0.6263 - val_mean_io_u: 0.4135 - val_recall: 0.3959 - val_precision: 0.2593
# Epoch 42/100
# 1/1 [==============================] - 0s 310ms/step - loss: 1.9847 - mean_io_u: 0.4021 - recall: 0.3700 - precision: 0.2298 - val_loss: 0.6107 - val_mean_io_u: 0.4135 - val_recall: 0.4159 - val_precision: 0.2710
# Epoch 43/100
# 1/1 [==============================] - 0s 321ms/step - loss: 1.8599 - mean_io_u: 0.4035 - recall: 0.3835 - precision: 0.2356 - val_loss: 0.5997 - val_mean_io_u: 0.4135 - val_recall: 0.4386 - val_precision: 0.2822
# Epoch 44/100
# 1/1 [==============================] - 0s 313ms/step - loss: 1.7554 - mean_io_u: 0.4068 - recall: 0.4006 - precision: 0.2418 - val_loss: 0.5926 - val_mean_io_u: 0.4135 - val_recall: 0.4619 - val_precision: 0.2917
# Epoch 45/100
# 1/1 [==============================] - 0s 331ms/step - loss: 1.6696 - mean_io_u: 0.4076 - recall: 0.4181 - precision: 0.2472 - val_loss: 0.5884 - val_mean_io_u: 0.4135 - val_recall: 0.4847 - val_precision: 0.3006
# Epoch 46/100
# 1/1 [==============================] - 0s 322ms/step - loss: 1.6010 - mean_io_u: 0.4084 - recall: 0.4340 - precision: 0.2516 - val_loss: 0.5859 - val_mean_io_u: 0.4135 - val_recall: 0.5039 - val_precision: 0.3083
# Epoch 47/100
# 1/1 [==============================] - 0s 308ms/step - loss: 1.5446 - mean_io_u: 0.4094 - recall: 0.4474 - precision: 0.2551 - val_loss: 0.5842 - val_mean_io_u: 0.4135 - val_recall: 0.5175 - val_precision: 0.3157
# Epoch 48/100
# 1/1 [==============================] - 0s 305ms/step - loss: 1.4934 - mean_io_u: 0.4107 - recall: 0.4559 - precision: 0.2579 - val_loss: 0.5823 - val_mean_io_u: 0.4135 - val_recall: 0.5235 - val_precision: 0.3230
# Epoch 49/100
# 1/1 [==============================] - 0s 295ms/step - loss: 1.4412 - mean_io_u: 0.4122 - recall: 0.4593 - precision: 0.2612 - val_loss: 0.5800 - val_mean_io_u: 0.4135 - val_recall: 0.5224 - val_precision: 0.3309
# Epoch 50/100
# 1/1 [==============================] - 0s 306ms/step - loss: 1.3847 - mean_io_u: 0.4132 - recall: 0.4578 - precision: 0.2659 - val_loss: 0.5772 - val_mean_io_u: 0.4135 - val_recall: 0.5143 - val_precision: 0.3422
# Epoch 51/100
# 1/1 [==============================] - 0s 299ms/step - loss: 1.3241 - mean_io_u: 0.4137 - recall: 0.4509 - precision: 0.2726 - val_loss: 0.5738 - val_mean_io_u: 0.4135 - val_recall: 0.4993 - val_precision: 0.3563
# Epoch 52/100
# 1/1 [==============================] - 0s 320ms/step - loss: 1.2612 - mean_io_u: 0.4144 - recall: 0.4400 - precision: 0.2809 - val_loss: 0.5701 - val_mean_io_u: 0.4135 - val_recall: 0.4797 - val_precision: 0.3738
# Epoch 53/100
# 1/1 [==============================] - 0s 311ms/step - loss: 1.1983 - mean_io_u: 0.4149 - recall: 0.4263 - precision: 0.2909 - val_loss: 0.5663 - val_mean_io_u: 0.4135 - val_recall: 0.4587 - val_precision: 0.3945
# Epoch 54/100
# 1/1 [==============================] - 0s 301ms/step - loss: 1.1377 - mean_io_u: 0.4150 - recall: 0.4078 - precision: 0.3010 - val_loss: 0.5627 - val_mean_io_u: 0.4135 - val_recall: 0.4319 - val_precision: 0.4178
# Epoch 55/100
# 1/1 [==============================] - 0s 314ms/step - loss: 1.0813 - mean_io_u: 0.4150 - recall: 0.3872 - precision: 0.3108 - val_loss: 0.5594 - val_mean_io_u: 0.4135 - val_recall: 0.4037 - val_precision: 0.4414
# Epoch 56/100
# 1/1 [==============================] - 0s 308ms/step - loss: 1.0302 - mean_io_u: 0.4150 - recall: 0.3651 - precision: 0.3206 - val_loss: 0.5568 - val_mean_io_u: 0.4135 - val_recall: 0.3769 - val_precision: 0.4711
# Epoch 57/100
# 1/1 [==============================] - 0s 299ms/step - loss: 0.9862 - mean_io_u: 0.4149 - recall: 0.3430 - precision: 0.3372 - val_loss: 0.5548 - val_mean_io_u: 0.4135 - val_recall: 0.3540 - val_precision: 0.4956
# Epoch 58/100
# 1/1 [==============================] - 0s 303ms/step - loss: 0.9504 - mean_io_u: 0.4149 - recall: 0.3234 - precision: 0.3587 - val_loss: 0.5534 - val_mean_io_u: 0.4135 - val_recall: 0.3289 - val_precision: 0.5153
# Epoch 59/100
# 1/1 [==============================] - 0s 303ms/step - loss: 0.9214 - mean_io_u: 0.4148 - recall: 0.3037 - precision: 0.3690 - val_loss: 0.5526 - val_mean_io_u: 0.4135 - val_recall: 0.3076 - val_precision: 0.5317
# Epoch 60/100
# 1/1 [==============================] - 0s 310ms/step - loss: 0.8971 - mean_io_u: 0.4148 - recall: 0.2872 - precision: 0.3764 - val_loss: 0.5521 - val_mean_io_u: 0.4135 - val_recall: 0.2907 - val_precision: 0.5437
# Epoch 61/100
# 1/1 [==============================] - 0s 303ms/step - loss: 0.8765 - mean_io_u: 0.4147 - recall: 0.2732 - precision: 0.3816 - val_loss: 0.5517 - val_mean_io_u: 0.4135 - val_recall: 0.2741 - val_precision: 0.5476
# Epoch 62/100
# 1/1 [==============================] - 0s 313ms/step - loss: 0.8596 - mean_io_u: 0.4147 - recall: 0.2619 - precision: 0.4043 - val_loss: 0.5513 - val_mean_io_u: 0.4135 - val_recall: 0.2621 - val_precision: 0.5532
# Epoch 63/100
# 1/1 [==============================] - 0s 305ms/step - loss: 0.8456 - mean_io_u: 0.4147 - recall: 0.2548 - precision: 0.4286 - val_loss: 0.5509 - val_mean_io_u: 0.4135 - val_recall: 0.2561 - val_precision: 0.5555
# Epoch 64/100
# 1/1 [==============================] - 0s 299ms/step - loss: 0.8327 - mean_io_u: 0.4147 - recall: 0.2493 - precision: 0.4388 - val_loss: 0.5505 - val_mean_io_u: 0.4135 - val_recall: 0.2534 - val_precision: 0.5589
# Epoch 65/100
# 1/1 [==============================] - 0s 318ms/step - loss: 0.8199 - mean_io_u: 0.4147 - recall: 0.2492 - precision: 0.4474 - val_loss: 0.5501 - val_mean_io_u: 0.4135 - val_recall: 0.2538 - val_precision: 0.5615
# Epoch 66/100
# 1/1 [==============================] - 0s 304ms/step - loss: 0.8067 - mean_io_u: 0.4147 - recall: 0.2530 - precision: 0.4537 - val_loss: 0.5499 - val_mean_io_u: 0.4135 - val_recall: 0.2577 - val_precision: 0.5645
# Epoch 67/100
# 1/1 [==============================] - 0s 301ms/step - loss: 0.7932 - mean_io_u: 0.4147 - recall: 0.2594 - precision: 0.4573 - val_loss: 0.5501 - val_mean_io_u: 0.4135 - val_recall: 0.2667 - val_precision: 0.5674
# Epoch 68/100
# 1/1 [==============================] - 0s 303ms/step - loss: 0.7801 - mean_io_u: 0.4147 - recall: 0.2676 - precision: 0.4595 - val_loss: 0.5506 - val_mean_io_u: 0.4135 - val_recall: 0.2783 - val_precision: 0.5693
# Epoch 69/100
# 1/1 [==============================] - 0s 300ms/step - loss: 0.7679 - mean_io_u: 0.4147 - recall: 0.2780 - precision: 0.4609 - val_loss: 0.5514 - val_mean_io_u: 0.4135 - val_recall: 0.2947 - val_precision: 0.5746
# Epoch 70/100
# 1/1 [==============================] - 0s 306ms/step - loss: 0.7571 - mean_io_u: 0.4147 - recall: 0.2903 - precision: 0.4622 - val_loss: 0.5526 - val_mean_io_u: 0.4135 - val_recall: 0.3088 - val_precision: 0.5773
# Epoch 71/100
# 1/1 [==============================] - 0s 300ms/step - loss: 0.7483 - mean_io_u: 0.4147 - recall: 0.3044 - precision: 0.4628 - val_loss: 0.5539 - val_mean_io_u: 0.4135 - val_recall: 0.3257 - val_precision: 0.5836
# Epoch 72/100
# 1/1 [==============================] - 0s 311ms/step - loss: 0.7414 - mean_io_u: 0.4147 - recall: 0.3174 - precision: 0.4613 - val_loss: 0.5553 - val_mean_io_u: 0.4135 - val_recall: 0.3416 - val_precision: 0.5898
# Epoch 73/100
# 1/1 [==============================] - 0s 319ms/step - loss: 0.7362 - mean_io_u: 0.4147 - recall: 0.3303 - precision: 0.4594 - val_loss: 0.5567 - val_mean_io_u: 0.4135 - val_recall: 0.3566 - val_precision: 0.5940
# Epoch 74/100
# 1/1 [==============================] - 0s 306ms/step - loss: 0.7323 - mean_io_u: 0.4147 - recall: 0.3418 - precision: 0.4582 - val_loss: 0.5578 - val_mean_io_u: 0.4135 - val_recall: 0.3663 - val_precision: 0.5982
# Epoch 75/100
# 1/1 [==============================] - 0s 322ms/step - loss: 0.7291 - mean_io_u: 0.4147 - recall: 0.3513 - precision: 0.4573 - val_loss: 0.5586 - val_mean_io_u: 0.4135 - val_recall: 0.3714 - val_precision: 0.5988
# Epoch 76/100
# 1/1 [==============================] - 0s 307ms/step - loss: 0.7258 - mean_io_u: 0.4148 - recall: 0.3588 - precision: 0.4578 - val_loss: 0.5590 - val_mean_io_u: 0.4135 - val_recall: 0.3741 - val_precision: 0.6005
# Epoch 77/100
# 1/1 [==============================] - 0s 304ms/step - loss: 0.7221 - mean_io_u: 0.4148 - recall: 0.3633 - precision: 0.4601 - val_loss: 0.5590 - val_mean_io_u: 0.4135 - val_recall: 0.3721 - val_precision: 0.6029
# Epoch 78/100
# 1/1 [==============================] - 0s 302ms/step - loss: 0.7177 - mean_io_u: 0.4148 - recall: 0.3647 - precision: 0.4636 - val_loss: 0.5586 - val_mean_io_u: 0.4135 - val_recall: 0.3679 - val_precision: 0.6038
# Epoch 79/100
# 1/1 [==============================] - 0s 303ms/step - loss: 0.7126 - mean_io_u: 0.4148 - recall: 0.3630 - precision: 0.4685 - val_loss: 0.5578 - val_mean_io_u: 0.4135 - val_recall: 0.3584 - val_precision: 0.6053
# Epoch 80/100
# 1/1 [==============================] - 0s 310ms/step - loss: 0.7075 - mean_io_u: 0.4147 - recall: 0.3593 - precision: 0.4742 - val_loss: 0.5568 - val_mean_io_u: 0.4135 - val_recall: 0.3504 - val_precision: 0.6078
# Epoch 81/100
# 1/1 [==============================] - 0s 310ms/step - loss: 0.7025 - mean_io_u: 0.4147 - recall: 0.3541 - precision: 0.4808 - val_loss: 0.5555 - val_mean_io_u: 0.4135 - val_recall: 0.3411 - val_precision: 0.6086
# Epoch 82/100
# 1/1 [==============================] - 0s 307ms/step - loss: 0.6982 - mean_io_u: 0.4147 - recall: 0.3479 - precision: 0.4881 - val_loss: 0.5543 - val_mean_io_u: 0.4135 - val_recall: 0.3303 - val_precision: 0.6073
# Epoch 83/100
# 1/1 [==============================] - 0s 305ms/step - loss: 0.6945 - mean_io_u: 0.4147 - recall: 0.3412 - precision: 0.4941 - val_loss: 0.5530 - val_mean_io_u: 0.4135 - val_recall: 0.3187 - val_precision: 0.6062
# Epoch 84/100
# 1/1 [==============================] - 0s 303ms/step - loss: 0.6913 - mean_io_u: 0.4147 - recall: 0.3357 - precision: 0.4990 - val_loss: 0.5519 - val_mean_io_u: 0.4135 - val_recall: 0.3088 - val_precision: 0.6065
# Epoch 85/100
# 1/1 [==============================] - 0s 305ms/step - loss: 0.6883 - mean_io_u: 0.4147 - recall: 0.3314 - precision: 0.5038 - val_loss: 0.5510 - val_mean_io_u: 0.4135 - val_recall: 0.3025 - val_precision: 0.6052
# Epoch 86/100
# 1/1 [==============================] - 0s 296ms/step - loss: 0.6854 - mean_io_u: 0.4147 - recall: 0.3280 - precision: 0.5063 - val_loss: 0.5502 - val_mean_io_u: 0.4135 - val_recall: 0.3002 - val_precision: 0.6066
# Epoch 87/100
# 1/1 [==============================] - 0s 305ms/step - loss: 0.6824 - mean_io_u: 0.4147 - recall: 0.3266 - precision: 0.5083 - val_loss: 0.5495 - val_mean_io_u: 0.4135 - val_recall: 0.2988 - val_precision: 0.6074
# Epoch 88/100
# 1/1 [==============================] - 0s 305ms/step - loss: 0.6793 - mean_io_u: 0.4147 - recall: 0.3275 - precision: 0.5106 - val_loss: 0.5490 - val_mean_io_u: 0.4135 - val_recall: 0.2989 - val_precision: 0.6080
# Epoch 89/100
# 1/1 [==============================] - 0s 310ms/step - loss: 0.6760 - mean_io_u: 0.4147 - recall: 0.3292 - precision: 0.5121 - val_loss: 0.5485 - val_mean_io_u: 0.4135 - val_recall: 0.3014 - val_precision: 0.6110
# Epoch 90/100
# 1/1 [==============================] - 0s 303ms/step - loss: 0.6726 - mean_io_u: 0.4147 - recall: 0.3318 - precision: 0.5135 - val_loss: 0.5480 - val_mean_io_u: 0.4135 - val_recall: 0.3039 - val_precision: 0.6138
# Epoch 91/100
# 1/1 [==============================] - 0s 305ms/step - loss: 0.6693 - mean_io_u: 0.4147 - recall: 0.3351 - precision: 0.5142 - val_loss: 0.5474 - val_mean_io_u: 0.4135 - val_recall: 0.3076 - val_precision: 0.6173
# Epoch 92/100
# 1/1 [==============================] - 0s 298ms/step - loss: 0.6661 - mean_io_u: 0.4147 - recall: 0.3389 - precision: 0.5162 - val_loss: 0.5467 - val_mean_io_u: 0.4135 - val_recall: 0.3102 - val_precision: 0.6198
# Epoch 93/100
# 1/1 [==============================] - 0s 301ms/step - loss: 0.6630 - mean_io_u: 0.4147 - recall: 0.3423 - precision: 0.5172 - val_loss: 0.5458 - val_mean_io_u: 0.4135 - val_recall: 0.3116 - val_precision: 0.6224
# Epoch 94/100
# 1/1 [==============================] - 0s 304ms/step - loss: 0.6599 - mean_io_u: 0.4147 - recall: 0.3451 - precision: 0.5184 - val_loss: 0.5447 - val_mean_io_u: 0.4135 - val_recall: 0.3118 - val_precision: 0.6243
# Epoch 95/100
# 1/1 [==============================] - 0s 303ms/step - loss: 0.6568 - mean_io_u: 0.4147 - recall: 0.3468 - precision: 0.5195 - val_loss: 0.5433 - val_mean_io_u: 0.4135 - val_recall: 0.3099 - val_precision: 0.6259
# Epoch 96/100
# 1/1 [==============================] - 0s 319ms/step - loss: 0.6537 - mean_io_u: 0.4147 - recall: 0.3475 - precision: 0.5208 - val_loss: 0.5415 - val_mean_io_u: 0.4135 - val_recall: 0.3081 - val_precision: 0.6300
# Epoch 97/100
# 1/1 [==============================] - 0s 304ms/step - loss: 0.6505 - mean_io_u: 0.4147 - recall: 0.3470 - precision: 0.5228 - val_loss: 0.5395 - val_mean_io_u: 0.4135 - val_recall: 0.3049 - val_precision: 0.6296
# Epoch 98/100
# 1/1 [==============================] - 0s 318ms/step - loss: 0.6472 - mean_io_u: 0.4147 - recall: 0.3453 - precision: 0.5249 - val_loss: 0.5373 - val_mean_io_u: 0.4135 - val_recall: 0.3000 - val_precision: 0.6298
# Epoch 99/100
# 1/1 [==============================] - 0s 305ms/step - loss: 0.6439 - mean_io_u: 0.4147 - recall: 0.3429 - precision: 0.5270 - val_loss: 0.5348 - val_mean_io_u: 0.4135 - val_recall: 0.2968 - val_precision: 0.6327
# Epoch 100/100
# 1/1 [==============================] - 0s 304ms/step - loss: 0.6405 - mean_io_u: 0.4147 - recall: 0.3391 - precision: 0.5295 - val_loss: 0.5322 - val_mean_io_u: 0.4135 - val_recall: 0.2905 - val_precision: 0.6342

# %% [markdown]
# ### Apply network to (unseen) test data

# %%
predicted_masks = model.predict(images_test, verbose=1)
predicted_masks = predicted_masks > 0.5
# Out:
# 1/1 [==============================] - 0s 242ms/step

# %%
# Visualise some results
def plot_predictions(
    raw_images,
    predictions,
    ground_truth,
    num_to_plot=2,
    fig_size=(15, 15),
    axes_pad=0.1,
):
    """
    Compare predicted & actual mask images

    :param raw_images: Array of raw data images
    :param predictions: Array of prediction mask images
    :param ground_truth: Array of ground truth mask images
    :param num_to_plot: How many random images to plot
    :param fig_size: Tuple of overall figure size
    :param axes_pad: Seperation of individual images
    """

    idx_to_plot = tuple(random.sample(range(0, len(raw_images)), num_to_plot))

    raw_images = raw_images[tuple([idx_to_plot])]
    predictions = np.squeeze(predictions)[tuple([idx_to_plot])]
    ground_truth = np.squeeze(ground_truth)[tuple([idx_to_plot])]

    fig = plt.figure(figsize=fig_size)
    grid = ImageGrid(
        fig,
        111,
        nrows_ncols=(num_to_plot, 3),
        axes_pad=axes_pad,
    )

    images = []
    for a, b, c in zip(raw_images, predictions, ground_truth):
        images.extend([a, b, c])

    for ax, im in zip(grid, images):
        ax.imshow(im)
        ax.axis("off")

    grid[0].title.set_text("Raw data")
    grid[1].title.set_text("Network prediction")
    grid[2].title.set_text("Ground truth")

# %%
plot_predictions(images_test, predicted_masks, masks_test, num_to_plot=5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2613229/3555514682.py in <module>
# ----> 1 plot_predictions(images_test, predicted_masks, masks_test, num_to_plot=5)
#
# /tmp/ipykernel_2613229/252569921.py in plot_predictions(raw_images, predictions, ground_truth, num_to_plot, fig_size, axes_pad)
#      19     """
#      20
# ---> 21     idx_to_plot = tuple(random.sample(range(0, len(raw_images)), num_to_plot))
#      22
#      23     raw_images = raw_images[tuple([idx_to_plot])]
#
# ~/.conda/envs/dl-icr/lib/python3.9/random.py in sample(self, population, k, counts)
#     447         randbelow = self._randbelow
#     448         if not 0 <= k <= n:
# --> 449             raise ValueError("Sample larger than population or is negative")
#     450         result = [None] * k
#     451         setsize = 21        # size of a small set minus size of an empty list
#
# ValueError: Sample larger than population or is negative

# %% [markdown]
# ## Limitations
# * Segmentation not perfect, lots of ways to improve (more training, augmentation, better network, adjust hyperparameters etc.)
# * We segmented *all* cells, and not *each* cell. We could further these masks (e.g. by using a watershed algorithm), or use an alternative, object detection network (e.g. [Mask R-CNN](https://arxiv.org/abs/1703.06870))
